# %% [markdown]
# # Classification Example

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %% [markdown]
# ### Open the file into a data frame

# %%
DATA_DIR = 'C:/Users/oit/Downloads'
FILE_NAME = 'income.csv'
data_path = os.path.join(DATA_DIR, FILE_NAME)
dat_income = pd.read_csv(data_path)

# %%
dat_income
# Out:
#        age          workclass      education  edyears          marital-status  \
# 0       39          State-gov      Bachelors       13           Never-married
# 1       50   Self-emp-not-inc      Bachelors       13      Married-civ-spouse
# 2       38            Private        HS-grad        9                Divorced
# 3       53            Private           11th        7      Married-civ-spouse
# 4       28            Private      Bachelors       13      Married-civ-spouse
# 5       37            Private        Masters       14      Married-civ-spouse
# 6       49            Private            9th        5   Married-spouse-absent
# 7       52   Self-emp-not-inc        HS-grad        9      Married-civ-spouse
# 8       31            Private        Masters       14           Never-married
# 9       42            Private      Bachelors       13      Married-civ-spouse
# 10      37            Private   Some-college       10      Married-civ-spouse
# 11      30          State-gov      Bachelors       13      Married-civ-spouse
# 12      23            Private      Bachelors       13           Never-married
# 13      32            Private     Assoc-acdm       12           Never-married
# 14      40            Private      Assoc-voc       11      Married-civ-spouse
# 15      34            Private        7th-8th        4      Married-civ-spouse
# 16      25   Self-emp-not-inc        HS-grad        9           Never-married
# 17      32            Private        HS-grad        9           Never-married
# 18      38            Private           11th        7      Married-civ-spouse
# 19      43   Self-emp-not-inc        Masters       14                Divorced
# 20      40            Private      Doctorate       16      Married-civ-spouse
# 21      54            Private        HS-grad        9               Separated
# 22      35        Federal-gov            9th        5      Married-civ-spouse
# 23      43            Private           11th        7      Married-civ-spouse
# 24      59            Private        HS-grad        9                Divorced
# 25      56          Local-gov      Bachelors       13      Married-civ-spouse
# 26      19            Private        HS-grad        9           Never-married
# 27      54                  ?   Some-college       10      Married-civ-spouse
# 28      39            Private        HS-grad        9                Divorced
# 29      49            Private        HS-grad        9      Married-civ-spouse
# ...    ...                ...            ...      ...                     ...
# 32531   30                  ?      Bachelors       13           Never-married
# 32532   34            Private      Doctorate       16      Married-civ-spouse
# 32533   54            Private      Bachelors       13      Married-civ-spouse
# 32534   37            Private   Some-college       10                Divorced
# 32535   22            Private           12th        8           Never-married
# 32536   34            Private      Bachelors       13           Never-married
# 32537   30            Private        HS-grad        9           Never-married
# 32538   38            Private      Bachelors       13                Divorced
# 32539   71                  ?      Doctorate       16      Married-civ-spouse
# 32540   45          State-gov        HS-grad        9               Separated
# 32541   41                  ?        HS-grad        9               Separated
# 32542   72                  ?        HS-grad        9      Married-civ-spouse
# 32543   45          Local-gov     Assoc-acdm       12                Divorced
# 32544   31            Private        Masters       14                Divorced
# 32545   39          Local-gov     Assoc-acdm       12      Married-civ-spouse
# 32546   37            Private     Assoc-acdm       12                Divorced
# 32547   43            Private        HS-grad        9      Married-civ-spouse
# 32548   65   Self-emp-not-inc    Prof-school       15           Never-married
# 32549   43          State-gov   Some-college       10                Divorced
# 32550   43   Self-emp-not-inc   Some-college       10      Married-civ-spouse
# 32551   32            Private           10th        6      Married-civ-spouse
# 32552   43            Private      Assoc-voc       11      Married-civ-spouse
# 32553   32            Private        Masters       14           Never-married
# 32554   53            Private        Masters       14      Married-civ-spouse
# 32555   22            Private   Some-college       10           Never-married
# 32556   27            Private     Assoc-acdm       12      Married-civ-spouse
# 32557   40            Private        HS-grad        9      Married-civ-spouse
# 32558   58            Private        HS-grad        9                 Widowed
# 32559   22            Private        HS-grad        9           Never-married
# 32560   52       Self-emp-inc        HS-grad        9      Married-civ-spouse
#
#                occupation     relationship                 race      sex  \
# 0            Adm-clerical    Not-in-family                White     Male
# 1         Exec-managerial          Husband                White     Male
# 2       Handlers-cleaners    Not-in-family                White     Male
# 3       Handlers-cleaners          Husband                Black     Male
# 4          Prof-specialty             Wife                Black   Female
# 5         Exec-managerial             Wife                White   Female
# 6           Other-service    Not-in-family                Black   Female
# 7         Exec-managerial          Husband                White     Male
# 8          Prof-specialty    Not-in-family                White   Female
# 9         Exec-managerial          Husband                White     Male
# 10        Exec-managerial          Husband                Black     Male
# 11         Prof-specialty          Husband   Asian-Pac-Islander     Male
# 12           Adm-clerical        Own-child                White   Female
# 13                  Sales    Not-in-family                Black     Male
# 14           Craft-repair          Husband   Asian-Pac-Islander     Male
# 15       Transport-moving          Husband   Amer-Indian-Eskimo     Male
# 16        Farming-fishing        Own-child                White     Male
# 17      Machine-op-inspct        Unmarried                White     Male
# 18                  Sales          Husband                White     Male
# 19        Exec-managerial        Unmarried                White   Female
# 20         Prof-specialty          Husband                White     Male
# 21          Other-service        Unmarried                Black   Female
# 22        Farming-fishing          Husband                Black     Male
# 23       Transport-moving          Husband                White     Male
# 24           Tech-support        Unmarried                White   Female
# 25           Tech-support          Husband                White     Male
# 26           Craft-repair        Own-child                White     Male
# 27                      ?          Husband   Asian-Pac-Islander     Male
# 28        Exec-managerial    Not-in-family                White     Male
# 29           Craft-repair          Husband                White     Male
# ...                   ...              ...                  ...      ...
# 32531                   ?    Not-in-family   Asian-Pac-Islander   Female
# 32532      Prof-specialty          Husband                White     Male
# 32533     Exec-managerial          Husband   Asian-Pac-Islander     Male
# 32534        Adm-clerical        Unmarried                White   Female
# 32535     Protective-serv        Own-child                Black     Male
# 32536     Exec-managerial    Not-in-family                White   Female
# 32537        Craft-repair    Not-in-family                Black     Male
# 32538      Prof-specialty        Unmarried                Black   Female
# 32539                   ?          Husband                White     Male
# 32540        Adm-clerical        Own-child                White   Female
# 32541                   ?    Not-in-family                Black   Female
# 32542                   ?          Husband                White     Male
# 32543      Prof-specialty        Unmarried                White   Female
# 32544       Other-service    Not-in-family                Other   Female
# 32545        Adm-clerical             Wife                White   Female
# 32546        Tech-support    Not-in-family                White   Female
# 32547   Machine-op-inspct          Husband                White     Male
# 32548      Prof-specialty    Not-in-family                White     Male
# 32549        Adm-clerical   Other-relative                White   Female
# 32550        Craft-repair          Husband                White     Male
# 32551   Handlers-cleaners          Husband   Amer-Indian-Eskimo     Male
# 32552               Sales          Husband                White     Male
# 32553        Tech-support    Not-in-family   Asian-Pac-Islander     Male
# 32554     Exec-managerial          Husband                White     Male
# 32555     Protective-serv    Not-in-family                White     Male
# 32556        Tech-support             Wife                White   Female
# 32557   Machine-op-inspct          Husband                White     Male
# 32558        Adm-clerical        Unmarried                White   Female
# 32559        Adm-clerical        Own-child                White     Male
# 32560     Exec-managerial             Wife                White   Female
#
#        hours-per-week  native-country  income
# 0                  40   United-States   <=50K
# 1                  13   United-States   <=50K
# 2                  40   United-States   <=50K
# 3                  40   United-States   <=50K
# 4                  40            Cuba   <=50K
# 5                  40   United-States   <=50K
# 6                  16         Jamaica   <=50K
# 7                  45   United-States    >50K
# 8                  50   United-States    >50K
# 9                  40   United-States    >50K
# 10                 80   United-States    >50K
# 11                 40           India    >50K
# 12                 30   United-States   <=50K
# 13                 50   United-States   <=50K
# 14                 40               ?    >50K
# 15                 45          Mexico   <=50K
# 16                 35   United-States   <=50K
# 17                 40   United-States   <=50K
# 18                 50   United-States   <=50K
# 19                 45   United-States    >50K
# 20                 60   United-States    >50K
# 21                 20   United-States   <=50K
# 22                 40   United-States   <=50K
# 23                 40   United-States   <=50K
# 24                 40   United-States   <=50K
# 25                 40   United-States    >50K
# 26                 40   United-States   <=50K
# 27                 60           South    >50K
# 28                 80   United-States   <=50K
# 29                 40   United-States   <=50K
# ...               ...             ...     ...
# 32531              99   United-States   <=50K
# 32532              60   United-States    >50K
# 32533              50           Japan    >50K
# 32534              39   United-States   <=50K
# 32535              35   United-States   <=50K
# 32536              55   United-States    >50K
# 32537              46   United-States   <=50K
# 32538              45   United-States    >50K
# 32539              10   United-States    >50K
# 32540              40   United-States   <=50K
# 32541              32   United-States   <=50K
# 32542              25   United-States   <=50K
# 32543              48   United-States   <=50K
# 32544              30   United-States   <=50K
# 32545              20   United-States    >50K
# 32546              40   United-States   <=50K
# 32547              40          Mexico   <=50K
# 32548              60   United-States   <=50K
# 32549              40   United-States   <=50K
# 32550              50   United-States   <=50K
# 32551              40   United-States   <=50K
# 32552              45   United-States   <=50K
# 32553              11          Taiwan   <=50K
# 32554              40   United-States    >50K
# 32555              40   United-States   <=50K
# 32556              38   United-States   <=50K
# 32557              40   United-States    >50K
# 32558              40   United-States   <=50K
# 32559              20   United-States   <=50K
# 32560              40   United-States    >50K
#
# [32561 rows x 12 columns]

# %% [markdown]
# ### Create a list of numeric features

# %%
numeric_features = ['age','edyears','hours-per-week']

# %%
dat_income[numeric_features]
# Out:
#        age  edyears  hours-per-week
# 0       39       13              40
# 1       50       13              13
# 2       38        9              40
# 3       53        7              40
# 4       28       13              40
# 5       37       14              40
# 6       49        5              16
# 7       52        9              45
# 8       31       14              50
# 9       42       13              40
# 10      37       10              80
# 11      30       13              40
# 12      23       13              30
# 13      32       12              50
# 14      40       11              40
# 15      34        4              45
# 16      25        9              35
# 17      32        9              40
# 18      38        7              50
# 19      43       14              45
# 20      40       16              60
# 21      54        9              20
# 22      35        5              40
# 23      43        7              40
# 24      59        9              40
# 25      56       13              40
# 26      19        9              40
# 27      54       10              60
# 28      39        9              80
# 29      49        9              40
# ...    ...      ...             ...
# 32531   30       13              99
# 32532   34       16              60
# 32533   54       13              50
# 32534   37       10              39
# 32535   22        8              35
# 32536   34       13              55
# 32537   30        9              46
# 32538   38       13              45
# 32539   71       16              10
# 32540   45        9              40
# 32541   41        9              32
# 32542   72        9              25
# 32543   45       12              48
# 32544   31       14              30
# 32545   39       12              20
# 32546   37       12              40
# 32547   43        9              40
# 32548   65       15              60
# 32549   43       10              40
# 32550   43       10              50
# 32551   32        6              40
# 32552   43       11              45
# 32553   32       14              11
# 32554   53       14              40
# 32555   22       10              40
# 32556   27       12              38
# 32557   40        9              40
# 32558   58        9              40
# 32559   22        9              20
# 32560   52        9              40
#
# [32561 rows x 3 columns]

# %% [markdown]
# ### Plot the numeric features

# %%
sns.pairplot(dat_income[numeric_features], plot_kws={"s": 3});

# %% [markdown]
# ### Get a correlation table on the numeric features

# %%
dat_income[numeric_features].corr()
# Out:
#                      age   edyears  hours-per-week
# age             1.000000  0.036527        0.068756
# edyears         0.036527  1.000000        0.148123
# hours-per-week  0.068756  0.148123        1.000000

# %% [markdown]
# ### Recode the target Variable (income) and rename as 'high-income'

# %%
dat_income = pd.concat([dat_income, pd.get_dummies(dat_income['income'], prefix='income', drop_first=True)], axis=1)
dat_income.rename(columns={'income_ >50K':'high-income'}, inplace=True)
dat_income.drop(['income'], inplace=True,axis=1)
dat_income
# Out:
#        age          workclass      education  edyears          marital-status  \
# 0       39          State-gov      Bachelors       13           Never-married
# 1       50   Self-emp-not-inc      Bachelors       13      Married-civ-spouse
# 2       38            Private        HS-grad        9                Divorced
# 3       53            Private           11th        7      Married-civ-spouse
# 4       28            Private      Bachelors       13      Married-civ-spouse
# 5       37            Private        Masters       14      Married-civ-spouse
# 6       49            Private            9th        5   Married-spouse-absent
# 7       52   Self-emp-not-inc        HS-grad        9      Married-civ-spouse
# 8       31            Private        Masters       14           Never-married
# 9       42            Private      Bachelors       13      Married-civ-spouse
# 10      37            Private   Some-college       10      Married-civ-spouse
# 11      30          State-gov      Bachelors       13      Married-civ-spouse
# 12      23            Private      Bachelors       13           Never-married
# 13      32            Private     Assoc-acdm       12           Never-married
# 14      40            Private      Assoc-voc       11      Married-civ-spouse
# 15      34            Private        7th-8th        4      Married-civ-spouse
# 16      25   Self-emp-not-inc        HS-grad        9           Never-married
# 17      32            Private        HS-grad        9           Never-married
# 18      38            Private           11th        7      Married-civ-spouse
# 19      43   Self-emp-not-inc        Masters       14                Divorced
# 20      40            Private      Doctorate       16      Married-civ-spouse
# 21      54            Private        HS-grad        9               Separated
# 22      35        Federal-gov            9th        5      Married-civ-spouse
# 23      43            Private           11th        7      Married-civ-spouse
# 24      59            Private        HS-grad        9                Divorced
# 25      56          Local-gov      Bachelors       13      Married-civ-spouse
# 26      19            Private        HS-grad        9           Never-married
# 27      54                  ?   Some-college       10      Married-civ-spouse
# 28      39            Private        HS-grad        9                Divorced
# 29      49            Private        HS-grad        9      Married-civ-spouse
# ...    ...                ...            ...      ...                     ...
# 32531   30                  ?      Bachelors       13           Never-married
# 32532   34            Private      Doctorate       16      Married-civ-spouse
# 32533   54            Private      Bachelors       13      Married-civ-spouse
# 32534   37            Private   Some-college       10                Divorced
# 32535   22            Private           12th        8           Never-married
# 32536   34            Private      Bachelors       13           Never-married
# 32537   30            Private        HS-grad        9           Never-married
# 32538   38            Private      Bachelors       13                Divorced
# 32539   71                  ?      Doctorate       16      Married-civ-spouse
# 32540   45          State-gov        HS-grad        9               Separated
# 32541   41                  ?        HS-grad        9               Separated
# 32542   72                  ?        HS-grad        9      Married-civ-spouse
# 32543   45          Local-gov     Assoc-acdm       12                Divorced
# 32544   31            Private        Masters       14                Divorced
# 32545   39          Local-gov     Assoc-acdm       12      Married-civ-spouse
# 32546   37            Private     Assoc-acdm       12                Divorced
# 32547   43            Private        HS-grad        9      Married-civ-spouse
# 32548   65   Self-emp-not-inc    Prof-school       15           Never-married
# 32549   43          State-gov   Some-college       10                Divorced
# 32550   43   Self-emp-not-inc   Some-college       10      Married-civ-spouse
# 32551   32            Private           10th        6      Married-civ-spouse
# 32552   43            Private      Assoc-voc       11      Married-civ-spouse
# 32553   32            Private        Masters       14           Never-married
# 32554   53            Private        Masters       14      Married-civ-spouse
# 32555   22            Private   Some-college       10           Never-married
# 32556   27            Private     Assoc-acdm       12      Married-civ-spouse
# 32557   40            Private        HS-grad        9      Married-civ-spouse
# 32558   58            Private        HS-grad        9                 Widowed
# 32559   22            Private        HS-grad        9           Never-married
# 32560   52       Self-emp-inc        HS-grad        9      Married-civ-spouse
#
#                occupation     relationship                 race      sex  \
# 0            Adm-clerical    Not-in-family                White     Male
# 1         Exec-managerial          Husband                White     Male
# 2       Handlers-cleaners    Not-in-family                White     Male
# 3       Handlers-cleaners          Husband                Black     Male
# 4          Prof-specialty             Wife                Black   Female
# 5         Exec-managerial             Wife                White   Female
# 6           Other-service    Not-in-family                Black   Female
# 7         Exec-managerial          Husband                White     Male
# 8          Prof-specialty    Not-in-family                White   Female
# 9         Exec-managerial          Husband                White     Male
# 10        Exec-managerial          Husband                Black     Male
# 11         Prof-specialty          Husband   Asian-Pac-Islander     Male
# 12           Adm-clerical        Own-child                White   Female
# 13                  Sales    Not-in-family                Black     Male
# 14           Craft-repair          Husband   Asian-Pac-Islander     Male
# 15       Transport-moving          Husband   Amer-Indian-Eskimo     Male
# 16        Farming-fishing        Own-child                White     Male
# 17      Machine-op-inspct        Unmarried                White     Male
# 18                  Sales          Husband                White     Male
# 19        Exec-managerial        Unmarried                White   Female
# 20         Prof-specialty          Husband                White     Male
# 21          Other-service        Unmarried                Black   Female
# 22        Farming-fishing          Husband                Black     Male
# 23       Transport-moving          Husband                White     Male
# 24           Tech-support        Unmarried                White   Female
# 25           Tech-support          Husband                White     Male
# 26           Craft-repair        Own-child                White     Male
# 27                      ?          Husband   Asian-Pac-Islander     Male
# 28        Exec-managerial    Not-in-family                White     Male
# 29           Craft-repair          Husband                White     Male
# ...                   ...              ...                  ...      ...
# 32531                   ?    Not-in-family   Asian-Pac-Islander   Female
# 32532      Prof-specialty          Husband                White     Male
# 32533     Exec-managerial          Husband   Asian-Pac-Islander     Male
# 32534        Adm-clerical        Unmarried                White   Female
# 32535     Protective-serv        Own-child                Black     Male
# 32536     Exec-managerial    Not-in-family                White   Female
# 32537        Craft-repair    Not-in-family                Black     Male
# 32538      Prof-specialty        Unmarried                Black   Female
# 32539                   ?          Husband                White     Male
# 32540        Adm-clerical        Own-child                White   Female
# 32541                   ?    Not-in-family                Black   Female
# 32542                   ?          Husband                White     Male
# 32543      Prof-specialty        Unmarried                White   Female
# 32544       Other-service    Not-in-family                Other   Female
# 32545        Adm-clerical             Wife                White   Female
# 32546        Tech-support    Not-in-family                White   Female
# 32547   Machine-op-inspct          Husband                White     Male
# 32548      Prof-specialty    Not-in-family                White     Male
# 32549        Adm-clerical   Other-relative                White   Female
# 32550        Craft-repair          Husband                White     Male
# 32551   Handlers-cleaners          Husband   Amer-Indian-Eskimo     Male
# 32552               Sales          Husband                White     Male
# 32553        Tech-support    Not-in-family   Asian-Pac-Islander     Male
# 32554     Exec-managerial          Husband                White     Male
# 32555     Protective-serv    Not-in-family                White     Male
# 32556        Tech-support             Wife                White   Female
# 32557   Machine-op-inspct          Husband                White     Male
# 32558        Adm-clerical        Unmarried                White   Female
# 32559        Adm-clerical        Own-child                White     Male
# 32560     Exec-managerial             Wife                White   Female
#
#        hours-per-week  native-country  high-income
# 0                  40   United-States            0
# 1                  13   United-States            0
# 2                  40   United-States            0
# 3                  40   United-States            0
# 4                  40            Cuba            0
# 5                  40   United-States            0
# 6                  16         Jamaica            0
# 7                  45   United-States            1
# 8                  50   United-States            1
# 9                  40   United-States            1
# 10                 80   United-States            1
# 11                 40           India            1
# 12                 30   United-States            0
# 13                 50   United-States            0
# 14                 40               ?            1
# 15                 45          Mexico            0
# 16                 35   United-States            0
# 17                 40   United-States            0
# 18                 50   United-States            0
# 19                 45   United-States            1
# 20                 60   United-States            1
# 21                 20   United-States            0
# 22                 40   United-States            0
# 23                 40   United-States            0
# 24                 40   United-States            0
# 25                 40   United-States            1
# 26                 40   United-States            0
# 27                 60           South            1
# 28                 80   United-States            0
# 29                 40   United-States            0
# ...               ...             ...          ...
# 32531              99   United-States            0
# 32532              60   United-States            1
# 32533              50           Japan            1
# 32534              39   United-States            0
# 32535              35   United-States            0
# 32536              55   United-States            1
# 32537              46   United-States            0
# 32538              45   United-States            1
# 32539              10   United-States            1
# 32540              40   United-States            0
# 32541              32   United-States            0
# 32542              25   United-States            0
# 32543              48   United-States            0
# 32544              30   United-States            0
# 32545              20   United-States            1
# 32546              40   United-States            0
# 32547              40          Mexico            0
# 32548              60   United-States            0
# 32549              40   United-States            0
# 32550              50   United-States            0
# 32551              40   United-States            0
# 32552              45   United-States            0
# 32553              11          Taiwan            0
# 32554              40   United-States            1
# 32555              40   United-States            0
# 32556              38   United-States            0
# 32557              40   United-States            1
# 32558              40   United-States            0
# 32559              20   United-States            0
# 32560              40   United-States            1
#
# [32561 rows x 12 columns]

# %% [markdown]
# ### Get Correlations for all numeric values and the target

# %%
target_feature = ['high-income']
dat_income[numeric_features+target_feature].corr()
# Out:
#                      age   edyears  hours-per-week  high-income
# age             1.000000  0.036527        0.068756     0.234037
# edyears         0.036527  1.000000        0.148123     0.335154
# hours-per-week  0.068756  0.148123        1.000000     0.229689
# high-income     0.234037  0.335154        0.229689     1.000000

# %% [markdown]
# ### Aggregate numeric values by nominal

# %%
dat_income.groupby('workclass').mean()
# Out:
#                          age    edyears  hours-per-week  high-income
# workclass
#  ?                 40.960240   9.260349       31.919390     0.104031
#  Federal-gov       42.590625  10.973958       41.379167     0.386458
#  Local-gov         41.751075  11.042045       40.982800     0.294792
#  Never-worked      20.571429   7.428571       28.428571     0.000000
#  Private           36.797585   9.879714       40.267096     0.218673
#  Self-emp-inc      46.017025  11.137097       48.818100     0.557348
#  Self-emp-not-inc  44.969697  10.226289       44.421881     0.284927
#  State-gov         39.436055  11.375963       39.031587     0.271957
#  Without-pay       47.785714   9.071429       32.714286     0.000000

# %%
dat_income.groupby('education').mean()
# Out:
#                      age  edyears  hours-per-week  high-income
# education
#  10th          37.429796      6.0       37.052519     0.066452
#  11th          32.355745      7.0       33.925957     0.051064
#  12th          32.000000      8.0       35.780600     0.076212
#  1st-4th       46.142857      2.0       38.255952     0.035714
#  5th-6th       42.885886      3.0       38.897898     0.048048
#  7th-8th       48.445820      4.0       39.366873     0.061920
#  9th           41.060311      5.0       38.044747     0.052529
#  Assoc-acdm    37.381443     12.0       40.504217     0.248360
#  Assoc-voc     38.553546     11.0       41.610709     0.261216
#  Bachelors     38.904949     13.0       42.614006     0.414753
#  Doctorate     47.702179     16.0       46.973366     0.740920
#  HS-grad       38.974479      9.0       40.575374     0.159509
#  Masters       44.049913     14.0       43.836332     0.556587
#  Preschool     42.764706      1.0       36.647059     0.000000
#  Prof-school   44.746528     15.0       47.425347     0.734375
#  Some-college  35.756275     10.0       38.852284     0.190235

# %%
dat_income.groupby('sex').mean()
# Out:
#                age    edyears  hours-per-week  high-income
# sex
#  Female  36.858230  10.035744       36.410361     0.109461
#  Male    39.433547  10.102891       42.428086     0.305737

# %% [markdown]
# ### Recode 'sex' column as Male = 1; rename column to 'male'

# %%
dat_income = pd.concat([dat_income, pd.get_dummies(dat_income['sex'], prefix='income', drop_first=True)], axis=1)
dat_income.rename(columns={'income_ Male':'male'}, inplace=True)
dat_income
# Out:
#        age          workclass      education  edyears          marital-status  \
# 0       39          State-gov      Bachelors       13           Never-married
# 1       50   Self-emp-not-inc      Bachelors       13      Married-civ-spouse
# 2       38            Private        HS-grad        9                Divorced
# 3       53            Private           11th        7      Married-civ-spouse
# 4       28            Private      Bachelors       13      Married-civ-spouse
# 5       37            Private        Masters       14      Married-civ-spouse
# 6       49            Private            9th        5   Married-spouse-absent
# 7       52   Self-emp-not-inc        HS-grad        9      Married-civ-spouse
# 8       31            Private        Masters       14           Never-married
# 9       42            Private      Bachelors       13      Married-civ-spouse
# 10      37            Private   Some-college       10      Married-civ-spouse
# 11      30          State-gov      Bachelors       13      Married-civ-spouse
# 12      23            Private      Bachelors       13           Never-married
# 13      32            Private     Assoc-acdm       12           Never-married
# 14      40            Private      Assoc-voc       11      Married-civ-spouse
# 15      34            Private        7th-8th        4      Married-civ-spouse
# 16      25   Self-emp-not-inc        HS-grad        9           Never-married
# 17      32            Private        HS-grad        9           Never-married
# 18      38            Private           11th        7      Married-civ-spouse
# 19      43   Self-emp-not-inc        Masters       14                Divorced
# 20      40            Private      Doctorate       16      Married-civ-spouse
# 21      54            Private        HS-grad        9               Separated
# 22      35        Federal-gov            9th        5      Married-civ-spouse
# 23      43            Private           11th        7      Married-civ-spouse
# 24      59            Private        HS-grad        9                Divorced
# 25      56          Local-gov      Bachelors       13      Married-civ-spouse
# 26      19            Private        HS-grad        9           Never-married
# 27      54                  ?   Some-college       10      Married-civ-spouse
# 28      39            Private        HS-grad        9                Divorced
# 29      49            Private        HS-grad        9      Married-civ-spouse
# ...    ...                ...            ...      ...                     ...
# 32531   30                  ?      Bachelors       13           Never-married
# 32532   34            Private      Doctorate       16      Married-civ-spouse
# 32533   54            Private      Bachelors       13      Married-civ-spouse
# 32534   37            Private   Some-college       10                Divorced
# 32535   22            Private           12th        8           Never-married
# 32536   34            Private      Bachelors       13           Never-married
# 32537   30            Private        HS-grad        9           Never-married
# 32538   38            Private      Bachelors       13                Divorced
# 32539   71                  ?      Doctorate       16      Married-civ-spouse
# 32540   45          State-gov        HS-grad        9               Separated
# 32541   41                  ?        HS-grad        9               Separated
# 32542   72                  ?        HS-grad        9      Married-civ-spouse
# 32543   45          Local-gov     Assoc-acdm       12                Divorced
# 32544   31            Private        Masters       14                Divorced
# 32545   39          Local-gov     Assoc-acdm       12      Married-civ-spouse
# 32546   37            Private     Assoc-acdm       12                Divorced
# 32547   43            Private        HS-grad        9      Married-civ-spouse
# 32548   65   Self-emp-not-inc    Prof-school       15           Never-married
# 32549   43          State-gov   Some-college       10                Divorced
# 32550   43   Self-emp-not-inc   Some-college       10      Married-civ-spouse
# 32551   32            Private           10th        6      Married-civ-spouse
# 32552   43            Private      Assoc-voc       11      Married-civ-spouse
# 32553   32            Private        Masters       14           Never-married
# 32554   53            Private        Masters       14      Married-civ-spouse
# 32555   22            Private   Some-college       10           Never-married
# 32556   27            Private     Assoc-acdm       12      Married-civ-spouse
# 32557   40            Private        HS-grad        9      Married-civ-spouse
# 32558   58            Private        HS-grad        9                 Widowed
# 32559   22            Private        HS-grad        9           Never-married
# 32560   52       Self-emp-inc        HS-grad        9      Married-civ-spouse
#
#                occupation     relationship                 race      sex  \
# 0            Adm-clerical    Not-in-family                White     Male
# 1         Exec-managerial          Husband                White     Male
# 2       Handlers-cleaners    Not-in-family                White     Male
# 3       Handlers-cleaners          Husband                Black     Male
# 4          Prof-specialty             Wife                Black   Female
# 5         Exec-managerial             Wife                White   Female
# 6           Other-service    Not-in-family                Black   Female
# 7         Exec-managerial          Husband                White     Male
# 8          Prof-specialty    Not-in-family                White   Female
# 9         Exec-managerial          Husband                White     Male
# 10        Exec-managerial          Husband                Black     Male
# 11         Prof-specialty          Husband   Asian-Pac-Islander     Male
# 12           Adm-clerical        Own-child                White   Female
# 13                  Sales    Not-in-family                Black     Male
# 14           Craft-repair          Husband   Asian-Pac-Islander     Male
# 15       Transport-moving          Husband   Amer-Indian-Eskimo     Male
# 16        Farming-fishing        Own-child                White     Male
# 17      Machine-op-inspct        Unmarried                White     Male
# 18                  Sales          Husband                White     Male
# 19        Exec-managerial        Unmarried                White   Female
# 20         Prof-specialty          Husband                White     Male
# 21          Other-service        Unmarried                Black   Female
# 22        Farming-fishing          Husband                Black     Male
# 23       Transport-moving          Husband                White     Male
# 24           Tech-support        Unmarried                White   Female
# 25           Tech-support          Husband                White     Male
# 26           Craft-repair        Own-child                White     Male
# 27                      ?          Husband   Asian-Pac-Islander     Male
# 28        Exec-managerial    Not-in-family                White     Male
# 29           Craft-repair          Husband                White     Male
# ...                   ...              ...                  ...      ...
# 32531                   ?    Not-in-family   Asian-Pac-Islander   Female
# 32532      Prof-specialty          Husband                White     Male
# 32533     Exec-managerial          Husband   Asian-Pac-Islander     Male
# 32534        Adm-clerical        Unmarried                White   Female
# 32535     Protective-serv        Own-child                Black     Male
# 32536     Exec-managerial    Not-in-family                White   Female
# 32537        Craft-repair    Not-in-family                Black     Male
# 32538      Prof-specialty        Unmarried                Black   Female
# 32539                   ?          Husband                White     Male
# 32540        Adm-clerical        Own-child                White   Female
# 32541                   ?    Not-in-family                Black   Female
# 32542                   ?          Husband                White     Male
# 32543      Prof-specialty        Unmarried                White   Female
# 32544       Other-service    Not-in-family                Other   Female
# 32545        Adm-clerical             Wife                White   Female
# 32546        Tech-support    Not-in-family                White   Female
# 32547   Machine-op-inspct          Husband                White     Male
# 32548      Prof-specialty    Not-in-family                White     Male
# 32549        Adm-clerical   Other-relative                White   Female
# 32550        Craft-repair          Husband                White     Male
# 32551   Handlers-cleaners          Husband   Amer-Indian-Eskimo     Male
# 32552               Sales          Husband                White     Male
# 32553        Tech-support    Not-in-family   Asian-Pac-Islander     Male
# 32554     Exec-managerial          Husband                White     Male
# 32555     Protective-serv    Not-in-family                White     Male
# 32556        Tech-support             Wife                White   Female
# 32557   Machine-op-inspct          Husband                White     Male
# 32558        Adm-clerical        Unmarried                White   Female
# 32559        Adm-clerical        Own-child                White     Male
# 32560     Exec-managerial             Wife                White   Female
#
#        hours-per-week  native-country  high-income  male
# 0                  40   United-States            0     1
# 1                  13   United-States            0     1
# 2                  40   United-States            0     1
# 3                  40   United-States            0     1
# 4                  40            Cuba            0     0
# 5                  40   United-States            0     0
# 6                  16         Jamaica            0     0
# 7                  45   United-States            1     1
# 8                  50   United-States            1     0
# 9                  40   United-States            1     1
# 10                 80   United-States            1     1
# 11                 40           India            1     1
# 12                 30   United-States            0     0
# 13                 50   United-States            0     1
# 14                 40               ?            1     1
# 15                 45          Mexico            0     1
# 16                 35   United-States            0     1
# 17                 40   United-States            0     1
# 18                 50   United-States            0     1
# 19                 45   United-States            1     0
# 20                 60   United-States            1     1
# 21                 20   United-States            0     0
# 22                 40   United-States            0     1
# 23                 40   United-States            0     1
# 24                 40   United-States            0     0
# 25                 40   United-States            1     1
# 26                 40   United-States            0     1
# 27                 60           South            1     1
# 28                 80   United-States            0     1
# 29                 40   United-States            0     1
# ...               ...             ...          ...   ...
# 32531              99   United-States            0     0
# 32532              60   United-States            1     1
# 32533              50           Japan            1     1
# 32534              39   United-States            0     0
# 32535              35   United-States            0     1
# 32536              55   United-States            1     0
# 32537              46   United-States            0     1
# 32538              45   United-States            1     0
# 32539              10   United-States            1     1
# 32540              40   United-States            0     0
# 32541              32   United-States            0     0
# 32542              25   United-States            0     1
# 32543              48   United-States            0     0
# 32544              30   United-States            0     0
# 32545              20   United-States            1     0
# 32546              40   United-States            0     0
# 32547              40          Mexico            0     1
# 32548              60   United-States            0     1
# 32549              40   United-States            0     0
# 32550              50   United-States            0     1
# 32551              40   United-States            0     1
# 32552              45   United-States            0     1
# 32553              11          Taiwan            0     1
# 32554              40   United-States            1     1
# 32555              40   United-States            0     1
# 32556              38   United-States            0     0
# 32557              40   United-States            1     1
# 32558              40   United-States            0     0
# 32559              20   United-States            0     1
# 32560              40   United-States            1     0
#
# [32561 rows x 13 columns]

# %% [markdown]
# ### Create list of training features.  Then code x and Y as Training and Target

# %%
training_features = ['age','edyears','hours-per-week','male']
X=dat_income[training_features]
y=dat_income[target_feature]

#Target is highincome

# %% [markdown]
# ### Split training and testing sets, then validate distribution.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.30, random_state=101)

# %%
y_train.mean()
# Out:
# high-income    0.241664
# dtype: float64

# %%
y_test.mean()
# Out:
# high-income    0.238817
# dtype: float64

# %% [markdown]
# ### Fit a decision tree model with a max-depth of 3

# %%
from sklearn.tree import DecisionTreeClassifier
class_tree = DecisionTreeClassifier(max_depth=3)
class_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
# Install a conda package in the current Jupyter kernel - You only need to do this once.
import sys
# !conda install --yes --prefix {sys.prefix} graphviz
# !conda install --yes --prefix {sys.prefix} pydotplus
# Also, make sure that graphviz is in your path.  See page 167 for details.
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\dhiru\Anaconda3
#
#   added / updated specs:
#     - graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.7.12               |           py37_0         3.0 MB
#     graphviz-2.38              |       hfd603c8_2        29.3 MB
#     ------------------------------------------------------------
#                                            Total:        32.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   graphviz           pkgs/main/win-64::graphviz-2.38-hfd603c8_2
#
# The following packages will be UPDATED:
#
#   conda                                       4.7.10-py37_0 --> 4.7.12-py37_0
#
#
#
# Downloading and Extracting Packages
#
# graphviz-2.38        | 29.3 MB   |            |   0%
# graphviz-2.38        | 29.3 MB   |            |   0%
# graphviz-2.38        | 29.3 MB   | 1          |   1%
# graphviz-2.38        | 29.3 MB   | 1          |   2%
# graphviz-2.38        | 29.3 MB   | 3          |   3%
# graphviz-2.38        | 29.3 MB   | 4          |   4%
# graphviz-2.38        | 29.3 MB   | 5          |   6%
# graphviz-2.38        | 29.3 MB   | 6          |   7%
# graphviz-2.38        | 29.3 MB   | 7          |   8%
# graphviz-2.38        | 29.3 MB   | 8          |   9%
# graphviz-2.38        | 29.3 MB   | 9          |  10%
# graphviz-2.38        | 29.3 MB   | #          |  11%
# graphviz-2.38        | 29.3 MB   | #1         |  12%
# graphviz-2.38        | 29.3 MB   | #2         |  13%
# graphviz-2.38        | 29.3 MB   | #4         |  14%
# graphviz-2.38        | 29.3 MB   | #5         |  15%
# graphviz-2.38        | 29.3 MB   | #6         |  16%
# graphviz-2.38        | 29.3 MB   | #7         |  18%
# graphviz-2.38        | 29.3 MB   | #8         |  19%
# graphviz-2.38        | 29.3 MB   | ##         |  20%
# graphviz-2.38        | 29.3 MB   | ##1        |  21%
# graphviz-2.38        | 29.3 MB   | ##2        |  22%
# graphviz-2.38        | 29.3 MB   | ##3        |  23%
# graphviz-2.38        | 29.3 MB   | ##4        |  24%
# graphviz-2.38        | 29.3 MB   | ##5        |  25%
# graphviz-2.38        | 29.3 MB   | ##6        |  26%
# graphviz-2.38        | 29.3 MB   | ##7        |  28%
# graphviz-2.38        | 29.3 MB   | ##9        |  29%
# graphviz-2.38        | 29.3 MB   | ###        |  31%
# graphviz-2.38        | 29.3 MB   | ###2       |  32%
# graphviz-2.38        | 29.3 MB   | ###4       |  34%
# graphviz-2.38        | 29.3 MB   | ###6       |  36%
# graphviz-2.38        | 29.3 MB   | ###8       |  39%
# graphviz-2.38        | 29.3 MB   | ####1      |  41%
# graphviz-2.38        | 29.3 MB   | ####4      |  44%
# graphviz-2.38        | 29.3 MB   | ####6      |  47%
# graphviz-2.38        | 29.3 MB   | ####8      |  49%
# graphviz-2.38        | 29.3 MB   | #####1     |  51%
# graphviz-2.38        | 29.3 MB   | #####3     |  54%
# graphviz-2.38        | 29.3 MB   | #####5     |  56%
# graphviz-2.38        | 29.3 MB   | #####8     |  58%
# graphviz-2.38        | 29.3 MB   | ######     |  60%
# graphviz-2.38        | 29.3 MB   | ######2    |  62%
# graphviz-2.38        | 29.3 MB   | ######4    |  64%
# graphviz-2.38        | 29.3 MB   | ######6    |  66%
# graphviz-2.38        | 29.3 MB   | ######8    |  68%
# graphviz-2.38        | 29.3 MB   | #######    |  71%
# graphviz-2.38        | 29.3 MB   | #######3   |  73%
# graphviz-2.38        | 29.3 MB   | #######5   |  75%
# graphviz-2.38        | 29.3 MB   | #######7   |  78%
# graphviz-2.38        | 29.3 MB   | #######9   |  80%
# graphviz-2.38        | 29.3 MB   | ########2  |  82%
# graphviz-2.38        | 29.3 MB   | ########4  |  85%
# graphviz-2.38        | 29.3 MB   | ########7  |  88%
# graphviz-2.38        | 29.3 MB   | ########9  |  90%
# graphviz-2.38        | 29.3 MB   | #########2 |  93%
# graphviz-2.38        | 29.3 MB   | #########5 |  96%
# graphviz-2.38        | 29.3 MB   | #########7 |  98%
# graphviz-2.38        | 29.3 MB   | #########9 | 100%
# graphviz-2.38        | 29.3 MB   | ########## | 100%
#
# conda-4.7.12         | 3.0 MB    |            |   0%
# conda-4.7.12         | 3.0 MB    | 5          |   5%
# conda-4.7.12         | 3.0 MB    | ###5       |  35%
# conda-4.7.12         | 3.0 MB    | ######3    |  64%
# conda-4.7.12         | 3.0 MB    | #########1 |  92%
# conda-4.7.12         | 3.0 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working...
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==2019.07=py37_0
#   - defaults/win-64::numba==0.44.1=py37hf9181ef_0
# done
#
# ## Package Plan ##
#
#   environment location: C:\Users\dhiru\Anaconda3
#
#   added / updated specs:
#     - pydotplus
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2019.03  |           py37_0           6 KB
#     anaconda-custom            |           py37_1           3 KB
#     ca-certificates-2019.10.16 |                0         163 KB
#     certifi-2019.9.11          |           py37_0         155 KB
#     pydotplus-2.0.2            |           py37_1          42 KB
#     tbb-2019.4                 |       h74a9793_0         156 KB
#     ------------------------------------------------------------
#                                            Total:         524 KB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/win-64::_anaconda_depends-2019.03-py37_0
#   pydotplus          pkgs/main/win-64::pydotplus-2.0.2-py37_1
#   tbb                pkgs/main/win-64::tbb-2019.4-h74a9793_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                               2019.5.15-0 --> 2019.10.16-0
#   certifi                                  2019.6.16-py37_0 --> 2019.9.11-py37_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2019.07-py37_0 --> custom-py37_1
#
#
#
# Downloading and Extracting Packages
#
# pydotplus-2.0.2      | 42 KB     |            |   0%
# pydotplus-2.0.2      | 42 KB     | ###8       |  38%
# pydotplus-2.0.2      | 42 KB     | ########## | 100%
#
# anaconda-custom      | 3 KB      |            |   0%
# anaconda-custom      | 3 KB      | ########## | 100%
#
# certifi-2019.9.11    | 155 KB    |            |   0%
# certifi-2019.9.11    | 155 KB    | ########## | 100%
#
# tbb-2019.4           | 156 KB    |            |   0%
# tbb-2019.4           | 156 KB    | ########2  |  82%
# tbb-2019.4           | 156 KB    | ########## | 100%
#
# _anaconda_depends-20 | 6 KB      |            |   0%
# _anaconda_depends-20 | 6 KB      | ########## | 100%
#
# ca-certificates-2019 | 163 KB    |            |   0%
# ca-certificates-2019 | 163 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
from IPython.display import Image  
import pydotplus

# %%
dot_data = StringIO()
export_graphviz(decision_tree=class_tree,
                out_file=dot_data,
                filled=True,
                rounded=True,
                proportion=True,
                feature_names = X_train.columns,
                class_names = ['Low', 'High'],
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# ### Create Confusion Matrix and other performance metrics

# %%
from sklearn.metrics import confusion_matrix
y_train_pred = class_tree.predict(X_train)
confusion_matrix(y_train,y_train_pred)

#diagonal(ii,jj) is correct rows, diagonal (ij,ji) are wrong, so bottom outbput says 16080 are coorect as per the model
# Out:
# array([[16080,  1204],
#        [ 3324,  2184]], dtype=int64)

# %%
pd.crosstab(y_train['high-income'], y_train_pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted      0     1    All
# True
# 0          16080  1204  17284
# 1           3324  2184   5508
# All        19404  3388  22792

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_true=y_train, y_pred=y_train_pred)
accuracy.round(3)
# Out:
# 0.801

# %%
pd.Series(data=class_tree.feature_importances_, index=X_train.columns).sort_values(ascending=False).round(3)
# Out:
# edyears           0.467
# age               0.352
# male              0.181
# hours-per-week    0.000
# dtype: float64

# %% [markdown]
# ### Predict using the test set

# %%
y_test_pred = class_tree.predict(X_test)
confusion_matrix(y_test,y_test_pred)
# Out:
# array([[6939,  497],
#        [1380,  953]], dtype=int64)

# %%
accuracy = accuracy_score(y_true=y_test, y_pred=y_test_pred)
accuracy.round(3)
# Out:
# 0.808

# %% [markdown]
# ### Using a Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, y_train)
y_train_pred_nb = nb.predict(X_train)
confusion_matrix(y_train,y_train_pred_nb)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([[15751,  1533],
#        [ 2920,  2588]], dtype=int64)

# %%
accuracy = accuracy_score(y_true=y_train, y_pred=y_train_pred_nb)
accuracy.round(3)
# Out:
# 0.805

# %% [markdown]
# ### Check accuracy of Test Set

# %%
y_test_pred_nb = nb.predict(X_test)
confusion_matrix(y_test,y_test_pred_nb)
# Out:
# array([[6801,  635],
#        [1212, 1121]], dtype=int64)

# %%
accuracy = accuracy_score(y_true=y_test, y_pred=y_test_pred_nb)
accuracy.round(3)
# Out:
# 0.811
